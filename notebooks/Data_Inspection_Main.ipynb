# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
df = pd.read_csv(os.getenv('csv_path'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  object
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
# ...

# %%
df.isnull().sum()*100/df.shape[0]#103024
# Out:
# Date                           0.000000
# Time                           0.000000
# Booking_ID                     0.000000
# Booking_Status                 0.000000
# Customer_ID                    0.000000
# Vehicle_Type                   0.000000
# Pickup_Location                0.000000
# Drop_Location                  0.000000
# V_TAT                         37.910584
# C_TAT                         37.910584
# Canceled_Rides_by_Customer    89.809171
# Canceled_Rides_by_Driver      82.107082
# Incomplete_Rides              37.910584
# Incomplete_Rides_Reason       96.189237
# Booking_Value                  0.000000
# Payment_Method                37.910584
# Ride_Distance                  0.000000
# Driver_Ratings                37.910584
# Customer_Rating               37.910584
# Vehicle Images                 0.000000
# dtype: float64

# %%
df['Booking_Status'].value_counts(dropna=False)
# Out:
# Booking_Status
# Success                 63967
# Canceled by Driver      18434
# Canceled by Customer    10499
# Driver Not Found        10124
# Name: count, dtype: int64

# %%
df.groupby(['Booking_Status'])[['V_TAT','C_TAT']].count()
# Out:
#                       V_TAT  C_TAT
# Booking_Status
# Canceled by Customer      0      0
# Canceled by Driver        0      0
# Driver Not Found          0      0
# Success               63967  63967

# %%
df.groupby(['Booking_Status'])[['Customer_Rating','Driver_Ratings']].count()
# Out:
#                       Customer_Rating  Driver_Ratings
# Booking_Status
# Canceled by Customer                0               0
# Canceled by Driver                  0               0
# Driver Not Found                    0               0
# Success                         63967           63967

# %%
df.groupby(['Booking_Status'])['Payment_Method'].count()
# Out:
# Booking_Status
# Canceled by Customer        0
# Canceled by Driver          0
# Driver Not Found            0
# Success                 63967
# Name: Payment_Method, dtype: int64

# %%
df['Incomplete_Rides'].value_counts(dropna=False)
# Out:
# Incomplete_Rides
# No     60041
# NaN    39057
# Yes     3926
# Name: count, dtype: int64

# %%
pd.crosstab(df['Booking_Status'],df['Incomplete_Rides'],dropna=False)
# Out:
# Incomplete_Rides         No   Yes    NaN
# Booking_Status
# Canceled by Customer      0     0  10499
# Canceled by Driver        0     0  18434
# Driver Not Found          0     0  10124
# Success               60041  3926      0

# %%
df['Incomplete_Rides_Reason'].value_counts(dropna=False)
# Out:
# Incomplete_Rides_Reason
# NaN                  99098
# Customer Demand       1601
# Vehicle Breakdown     1591
# Other Issue            734
# Name: count, dtype: int64

# %%
pd.crosstab(df['Booking_Status'],df['Incomplete_Rides_Reason'],dropna=False)
# Out:
# Incomplete_Rides_Reason  Customer Demand  Other Issue  Vehicle Breakdown  \
# Booking_Status
# Canceled by Customer                   0            0                  0
# Canceled by Driver                     0            0                  0
# Driver Not Found                       0            0                  0
# Success                             1601          734               1591
#
# Incomplete_Rides_Reason    NaN
# Booking_Status
# Canceled by Customer     10499
# Canceled by Driver       18434
# Driver Not Found         10124
# Success                  60041

# %%
pd.crosstab(df['Booking_Status'],df['Canceled_Rides_by_Customer'],dropna=False)
# Out:
# Canceled_Rides_by_Customer  AC is Not working  Change of plans  \
# Booking_Status
# Canceled by Customer                     1568             2081
# Canceled by Driver                          0                0
# Driver Not Found                            0                0
# Success                                     0                0
#
# Canceled_Rides_by_Customer  Driver asked to cancel  \
# Booking_Status
# Canceled by Customer                          2670
# Canceled by Driver                               0
# Driver Not Found                                 0
# Success                                          0
#
# Canceled_Rides_by_Customer  Driver is not moving towards pickup location  \
# Booking_Status
# Canceled by Customer                                                3175
# Canceled by Driver                                                     0
# Driver Not Found                                                       0
# ...

# %%
pd.crosstab(df['Booking_Status'],df['Canceled_Rides_by_Driver'],dropna=False)
# Out:
# Canceled_Rides_by_Driver  Customer related issue  Customer was coughing/sick  \
# Booking_Status
# Canceled by Customer                           0                           0
# Canceled by Driver                          5413                        3654
# Driver Not Found                               0                           0
# Success                                        0                           0
#
# Canceled_Rides_by_Driver  More than permitted people in there  \
# Booking_Status
# Canceled by Customer                                        0
# Canceled by Driver                                       2825
# Driver Not Found                                            0
# Success                                                     0
#
# Canceled_Rides_by_Driver  Personal & Car related issue    NaN
# Booking_Status
# Canceled by Customer                                 0  10499
# Canceled by Driver                                6542      0
# ...

# %%
df
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 0       2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3       2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4       2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                     ...       ...            ...                   ...
# 103019  2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
# ...

# %%
df[df['Incomplete_Rides'] == 'Yes'].shape
# Out:
# (3926, 20)

# %%
df[df['Incomplete_Rides'] == 'No'].shape
# Out:
# (60041, 20)

# %%
df['Incomplete_Rides_Reason'].value_counts(dropna=False)
# Out:
# Incomplete_Rides_Reason
# NaN                  99098
# Customer Demand       1601
# Vehicle Breakdown     1591
# Other Issue            734
# Name: count, dtype: int64

# %%
df[df['Customer_Rating'].notna()].shape
# Out:
# (63967, 20)

# %%
df[df['Driver_Ratings'].notna()].shape
# Out:
# (63967, 20)

# %%
df[df['Incomplete_Rides']=='No']
# Out:
#                        Date      Time     Booking_ID Booking_Status  \
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040        Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879        Success
# 4       2024-07-02 09:02:00  09:02:00  CNR1797421769        Success
# 5       2024-07-13 04:42:00  04:42:00  CNR8787177882        Success
# 6       2024-07-23 09:51:00  09:51:00  CNR3612067560        Success
# ...                     ...       ...            ...            ...
# 103019  2024-07-31 09:06:00  09:06:00  CNR9488489435        Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100        Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233        Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035        Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721        Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 1        CID225428         Bike        Magadi Road        Varthur  203.0
# ...

# %%
df[df['Incomplete_Rides']=='Yes']
# Out:
#                        Date      Time     Booking_ID Booking_Status  \
# 38      2024-07-03 00:58:00  00:58:00  CNR5176704322        Success
# 49      2024-07-26 13:20:00  13:20:00  CNR9312632867        Success
# 70      2024-07-29 19:40:00  19:40:00  CNR7924302885        Success
# 93      2024-07-22 12:51:00  12:51:00  CNR1640228587        Success
# 101     2024-07-13 02:55:00  02:55:00  CNR7623690602        Success
# ...                     ...       ...            ...            ...
# 102859  2024-07-31 21:33:00  21:33:00  CNR5546265534        Success
# 102870  2024-07-31 21:39:00  21:39:00  CNR1954831907        Success
# 102973  2024-07-31 08:03:00  08:03:00  CNR1271821250        Success
# 102978  2024-07-31 10:46:00  10:46:00  CNR4652634649        Success
# 103011  2024-07-31 07:01:00  07:01:00  CNR5427755403        Success
#
#        Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# ...

# %%
df['Booking_ID'].nunique()
# Out:
# 103024

# %%
df['Customer_ID'].nunique()
# Out:
# 94544

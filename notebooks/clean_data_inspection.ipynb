# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
df = pd.read_csv(os.getenv("csv_path"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  object
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       103024 non-null  float64
#  9   C_TAT                       103024 non-null  float64
#  10  Canceled_Rides_by_Customer  103024 non-null  object
#  11  Canceled_Rides_by_Driver    103024 non-null  object
#  12  Incomplete_Rides            103024 non-null  object
#  13  Incomplete_Rides_Reason     103024 non-null  object
#  14  Booking_Value               103024 non-null  int64
#  15  Payment_Method              103024 non-null  object
#  16  Ride_Distance               103024 non-null  int64
#  17  Driver_Ratings              103024 non-null  float64
#  18  Customer_Rating             103024 non-null  float64
#  19  Is_Rated_Ride               103024 non-null  int64
#  20  TAT_Applicable              103024 non-null  int64
# dtypes: float64(4), int64(4), object(13)
# memory usage: 16.5+ MB

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 0       2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3       2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4       2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                     ...       ...            ...                   ...
# 103019  2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 0        CID713523  Prime Sedan        Tumkur Road       RT Nagar   -1.0
# 1        CID225428         Bike        Magadi Road        Varthur  203.0
# 2        CID270156    Prime SUV      Sahakar Nagar        Varthur  238.0
# 3        CID581320        eBike         HSR Layout    Vijayanagar   -1.0
# 4        CID939555         Mini        Rajajinagar    Chamarajpet  252.0
# ...            ...          ...                ...            ...    ...
# 103019   CID371654   Prime Plus      Richmond Town        Varthur  245.0
# 103020   CID334158         Auto        Vijayanagar  Richmond Town   84.0
# 103021   CID113188    Prime SUV  Bannerghatta Road       JP Nagar   35.0
# 103022   CID118301        eBike        Indiranagar    Magadi Road  210.0
# 103023   CID217959         Auto             Ulsoor         Hennur  175.0
#
#         C_TAT                    Canceled_Rides_by_Customer  \
# 0        -1.0                            Canceled by Driver
# 1        30.0                                 Ride Complete
# 2       130.0                                 Ride Complete
# 3        -1.0  Driver is not moving towards pickup location
# 4        80.0                                 Ride Complete
# ...       ...                                           ...
# 103019   35.0                                 Ride Complete
# 103020  145.0                                 Ride Complete
# 103021   75.0                                 Ride Complete
# 103022  140.0                                 Ride Complete
# 103023  125.0                                 Ride Complete
#
#             Canceled_Rides_by_Driver Incomplete_Rides Incomplete_Rides_Reason  \
# 0       Personal & Car related issue              Yes      Canceled by Driver
# 1                      Ride Complete               No           Ride Complete
# 2                      Ride Complete               No           Ride Complete
# 3               Canceled by Customer              Yes    Canceled by Customer
# 4                      Ride Complete               No           Ride Complete
# ...                              ...              ...                     ...
# 103019                 Ride Complete               No           Ride Complete
# 103020                 Ride Complete               No           Ride Complete
# 103021                 Ride Complete               No           Ride Complete
# 103022                 Ride Complete               No           Ride Complete
# 103023                 Ride Complete               No           Ride Complete
#
#         Booking_Value  Payment_Method  Ride_Distance  Driver_Ratings  \
# 0                 444  Not Applicable              0            -1.0
# 1                 158            Cash             13             4.1
# 2                 386             UPI             40             4.2
# 3                 384  Not Applicable              0            -1.0
# 4                 822     Credit Card             45             4.0
# ...               ...             ...            ...             ...
# 103019            111            Cash             41             3.6
# 103020           1097             UPI             17             4.3
# 103021           2201            Cash             37             3.6
# 103022            267             UPI             47             3.4
# 103023            462             UPI              3             4.8
#
#         Customer_Rating  Is_Rated_Ride  TAT_Applicable
# 0                  -1.0              0               0
# 1                   4.0              1               1
# 2                   4.8              1               1
# 3                  -1.0              0               0
# 4                   3.0              1               1
# ...                 ...            ...             ...
# 103019              3.8              1               1
# 103020              3.3              1               1
# 103021              3.2              1               1
# 103022              3.1              1               1
# 103023              4.4              1               1
#
# [103024 rows x 21 columns]

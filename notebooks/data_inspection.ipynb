# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
df = pd.read_excel(os.getenv('xl_path'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[ns]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
# ...

# %%
df.isnull().sum()*100/df.shape[0]#103024
# Out:
# Date                           0.000000
# Time                           0.000000
# Booking_ID                     0.000000
# Booking_Status                 0.000000
# Customer_ID                    0.000000
# Vehicle_Type                   0.000000
# Pickup_Location                0.000000
# Drop_Location                  0.000000
# V_TAT                         37.910584
# C_TAT                         37.910584
# Canceled_Rides_by_Customer    89.809171
# Canceled_Rides_by_Driver      82.107082
# Incomplete_Rides              37.910584
# Incomplete_Rides_Reason       96.189237
# Booking_Value                  0.000000
# Payment_Method                37.910584
# Ride_Distance                  0.000000
# Driver_Ratings                37.910584
# Customer_Rating               37.910584
# Vehicle Images                 0.000000
# dtype: float64

# %%
df.duplicated().sum()#no duplicate rows
# Out:
# np.int64(0)

# %%
for col in df.columns:
    print(f"{col} - {df[col].nunique()}")
# Out:
# Date - 40214
# Time - 1440
# Booking_ID - 103024
# Booking_Status - 4
# Customer_ID - 94544
# Vehicle_Type - 7
# Pickup_Location - 50
# Drop_Location - 50
# V_TAT - 40
# C_TAT - 25
# Canceled_Rides_by_Customer - 5
# Canceled_Rides_by_Driver - 4
# Incomplete_Rides - 2
# Incomplete_Rides_Reason - 3
# Booking_Value - 2883
# Payment_Method - 4
# Ride_Distance - 50
# Driver_Ratings - 21
# Customer_Rating - 21
# Vehicle Images - 7

# %%
df['Booking_Status'].value_counts()
# Out:
# Booking_Status
# Success                 63967
# Canceled by Driver      18434
# Canceled by Customer    10499
# Driver Not Found        10124
# Name: count, dtype: int64

# %%
df.groupby('Booking_Status')[['V_TAT','C_TAT']].count()
# Out:
#                       V_TAT  C_TAT
# Booking_Status
# Canceled by Customer      0      0
# Canceled by Driver        0      0
# Driver Not Found          0      0
# Success               63967  63967

# %%
df.groupby('Booking_Status')['Payment_Method'].count()
# Out:
# Booking_Status
# Canceled by Customer        0
# Canceled by Driver          0
# Driver Not Found            0
# Success                 63967
# Name: Payment_Method, dtype: int64

# %%
df.groupby('Booking_Status')['Customer_Rating'].count()
# Out:
# Booking_Status
# Canceled by Customer        0
# Canceled by Driver          0
# Driver Not Found            0
# Success                 63967
# Name: Customer_Rating, dtype: int64

# %%
for col in df.columns:
    print(f"{col} - {df[col].astype(str).str.len().max()}")
# Out:
# Date - 19
# Time - 8
# Booking_ID - 13
# Booking_Status - 20
# Customer_ID - 9
# Vehicle_Type - 11
# Pickup_Location - 20
# Drop_Location - 20
# V_TAT - 5
# C_TAT - 5
# Canceled_Rides_by_Customer - 44
# Canceled_Rides_by_Driver - 35
# Incomplete_Rides - 3
# Incomplete_Rides_Reason - 17
# Booking_Value - 4
# Payment_Method - 11
# Ride_Distance - 2
# Driver_Ratings - 3
# Customer_Rating - 3
# Vehicle Images - 57

# %%
df[df['Booking_Status']=='Canceled by Customer'].shape
# Out:
# (10499, 20)

# %%
df['Canceled_Rides_by_Customer'].count()
# Out:
# np.int64(10499)

# %%
df[df['Booking_Status']=='Canceled by Driver'].shape
# Out:
# (18434, 20)

# %%
df['Canceled_Rides_by_Driver'].count()
# Out:
# np.int64(18434)

# %%
# for every cancelstatus by driver|customer, there is a response in cancelled_ride_by_driver|customer

# %%
df['Incomplete_Rides_Reason'].value_counts(dropna=False)
# Out:
# Incomplete_Rides_Reason
# NaN                  99098
# Customer Demand       1601
# Vehicle Breakdown     1591
# Other Issue            734
# Name: count, dtype: int64

# %%
df['Incomplete_Rides'].value_counts(dropna=False)
# Out:
# Incomplete_Rides
# No     60041
# NaN    39057
# Yes     3926
# Name: count, dtype: int64

# %%
df
# Out:
#                       Date      Time     Booking_ID        Booking_Status  \
# 0      2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1      2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2      2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3      2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4      2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                    ...       ...            ...                   ...
# 103019 2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020 2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021 2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022 2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023 2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# ...

# %%
df[df['Booking_Status']=='Success']['Incomplete_Rides'].count()
# Out:
# np.int64(63967)

# %%
df['Vehicle_Type'].value_counts(dropna=False)
# Out:
# Vehicle_Type
# Prime Sedan    14877
# eBike          14816
# Auto           14755
# Prime Plus     14707
# Bike           14662
# Prime SUV      14655
# Mini           14552
# Name: count, dtype: int64

# %%
df[df['Booking_Status']=='Success']['Incomplete_Rides_Reason'].value_counts(dropna=False)
# Out:
# Incomplete_Rides_Reason
# NaN                  60041
# Customer Demand       1601
# Vehicle Breakdown     1591
# Other Issue            734
# Name: count, dtype: int64

# %%
df[df['Booking_Status']=='Canceled by Customer']['Incomplete_Rides_Reason'].value_counts(dropna=False)
# Out:
# Incomplete_Rides_Reason
# NaN    10499
# Name: count, dtype: int64

# %%
df['Canceled_Rides_by_Customer'].value_counts(dropna=False)
# Out:
# Canceled_Rides_by_Customer
# NaN                                             92525
# Driver is not moving towards pickup location     3175
# Driver asked to cancel                           2670
# Change of plans                                  2081
# AC is Not working                                1568
# Wrong Address                                    1005
# Name: count, dtype: int64

# %%
df.loc[df['Booking_Status']=='Canceled by Customer',['Canceled_Rides_by_Customer','Canceled_Rides_by_Driver']]
# Out:
#                           Canceled_Rides_by_Customer Canceled_Rides_by_Driver
# 3       Driver is not moving towards pickup location                      NaN
# 29                            Driver asked to cancel                      NaN
# 32      Driver is not moving towards pickup location                      NaN
# 65                                 AC is Not working                      NaN
# 99                            Driver asked to cancel                      NaN
# ...                                              ...                      ...
# 102960  Driver is not moving towards pickup location                      NaN
# 102977  Driver is not moving towards pickup location                      NaN
# 102983  Driver is not moving towards pickup location                      NaN
# 102994                        Driver asked to cancel                      NaN
# 102999  Driver is not moving towards pickup location                      NaN
#
# [10499 rows x 2 columns]
